# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap

# %%
df = pd.read_csv('survey_results_public.csv')
df
# Out:
#        ResponseId     Q120                      MainBranch  \
# 0               1  I agree                   None of these
# 1               2  I agree  I am a developer by profession
# 2               3  I agree  I am a developer by profession
# 3               4  I agree  I am a developer by profession
# 4               5  I agree  I am a developer by profession
# ...           ...      ...                             ...
# 89179       89180  I agree  I am a developer by profession
# 89180       89181  I agree  I am a developer by profession
# 89181       89182  I agree     I code primarily as a hobby
# 89182       89183  I agree  I am a developer by profession
# 89183       89184  I agree  I am a developer by profession
#
#                       Age                                         Employment  \
# 0         18-24 years old                                                NaN
# 1         25-34 years old                                Employed, full-time
# ...

# %%
# სტრიქონი
df.loc[1]
# Out:
# ResponseId                                                             2
# Q120                                                             I agree
# MainBranch                                I am a developer by profession
# Age                                                      25-34 years old
# Employment                                           Employed, full-time
#                                              ...
# ProfessionalTech       DevOps function;Microservices;Automated testin...
# Industry               Information Services, IT, Software Development...
# SurveyLength                                       Appropriate in length
# SurveyEase                                                          Easy
# ConvertedCompYearly                                             285000.0
# Name: 1, Length: 84, dtype: object

# %%
#სვეტი
df['Age']
# Out:
# 0           18-24 years old
# 1           25-34 years old
# 2           45-54 years old
# 3           25-34 years old
# 4           25-34 years old
#                 ...
# 89179       25-34 years old
# 89180       18-24 years old
# 89181     Prefer not to say
# 89182    Under 18 years old
# 89183       35-44 years old
# Name: Age, Length: 89184, dtype: object

# %%
df.set_index('Age', inplace=True)

# %%
df
# Out:
#                                         MainBranch  \
# Age
# 18-24 years old                      None of these
# 25-34 years old     I am a developer by profession
# 45-54 years old     I am a developer by profession
# 25-34 years old     I am a developer by profession
# 25-34 years old     I am a developer by profession
# ...                                            ...
# 25-34 years old     I am a developer by profession
# 18-24 years old     I am a developer by profession
# Prefer not to say      I code primarily as a hobby
# Under 18 years old  I am a developer by profession
# 35-44 years old     I am a developer by profession
#
#                                               RemoteWork  \
# Age
# 18-24 years old                                      NaN
# 25-34 years old                                   Remote
# 45-54 years old     Hybrid (some remote, some in-person)
# 25-34 years old     Hybrid (some remote, some in-person)
# ...

# %%
Filtration = (df['RemoteWork'] == 'Remote') & (df.index == 'Under 18 years old')

filtered = df.loc[Filtration]
filtered
# Out:
#                     ResponseId     Q120  \
# Age
# Under 18 years old          19  I agree
# Under 18 years old        1054  I agree
# Under 18 years old        1156  I agree
# Under 18 years old        1465  I agree
# Under 18 years old        1493  I agree
# ...                        ...      ...
# Under 18 years old       88520  I agree
# Under 18 years old       88681  I agree
# Under 18 years old       88873  I agree
# Under 18 years old       88880  I agree
# Under 18 years old       88930  I agree
#
#                                                            MainBranch  \
# Age
# Under 18 years old                     I am a developer by profession
# Under 18 years old                     I am a developer by profession
# Under 18 years old                              I am learning to code
# Under 18 years old                     I am a developer by profession
# Under 18 years old                        I code primarily as a hobby
# ...

# %%
sorting = df.sort_values(by=['ConvertedCompYearly', 'ResponseId'], ascending=[True, True])
sorting
# Out:
#                     ResponseId     Q120                      MainBranch  \
# Age
# 25-34 years old           2244  I agree  I am a developer by profession
# 25-34 years old           3930  I agree  I am a developer by profession
# 25-34 years old           5725  I agree  I am a developer by profession
# 18-24 years old           8863  I agree  I am a developer by profession
# 25-34 years old          13709  I agree  I am a developer by profession
# ...                        ...      ...                             ...
# 25-34 years old          89180  I agree  I am a developer by profession
# 18-24 years old          89181  I agree  I am a developer by profession
# Prefer not to say        89182  I agree     I code primarily as a hobby
# Under 18 years old       89183  I agree  I am a developer by profession
# 35-44 years old          89184  I agree  I am a developer by profession
#
#                                                            Employment  \
# Age
# ...

# %%
df.describe()
# Out:
#           CompTotal       WorkExp  ConvertedCompYearly
# count  4.822500e+04  43579.000000         4.801900e+04
# mean   1.036807e+42     11.405126         1.031101e+05
# std    2.276847e+44      9.051989         6.814188e+05
# min    0.000000e+00      0.000000         1.000000e+00
# 25%    6.300000e+04      5.000000         4.390700e+04
# 50%    1.150000e+05      9.000000         7.496300e+04
# 75%    2.300000e+05     16.000000         1.216410e+05
# max    5.000000e+46     50.000000         7.435143e+07

# %%
df.WorkExp.mean()
# Out:
# 11.405126322311204

# %%
df.ConvertedCompYearly.std()
# Out:
# 681418.8387120209

# %%
df.CompTotal.median()
# Out:
# 115000.0

# %%
df.CompTotal.max()
# Out:
# 4.999999999999999e+46

# %%
df.ConvertedCompYearly.min()
# Out:
# 1.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Sample DataFrame with more data points for demonstration
data = {
    'EdLevel': np.random.choice(['Primary/elementary school', 'Secondary school', 
                                  'Some college/university study without earning a degree', 
                                  'Associate degree', 'Bachelor’s degree', 'Master’s degree', 
                                  'Professional degree', 'Something else'], 
                                  size=5000, p=[0.05, 0.1, 0.15, 0.1, 0.2, 0.15, 0.05, 0.2])
}
df = pd.DataFrame(data)

ed_level_counts = df['EdLevel'].value_counts().sort_index()

plt.figure(figsize=(10, 6))
plt.bar(ed_level_counts.index, ed_level_counts.values, color='skyblue')
plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Distribution of Education Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df = df.dropna(subset=['TimeAnswering'])

count_less_than_15 = df['TimeAnswering'].str.count('Less than 15 minutes a day').sum()
count_15_to_30 = df['TimeAnswering'].str.count('15-30 minutes a day').sum()
count_30_to_60 = df['TimeAnswering'].str.count('30-60 minutes a day').sum()
count_60_to_120 = df['TimeAnswering'].str.count('60-120 minutes a day').sum()
count_over_120 = df['TimeAnswering'].str.count('Over 120 minutes a day').sum()

fig, ax = plt.subplots(figsize=(8, 6))

labels = ['Less than 15 minutes', '15-30 minutes', '30-60 minutes', '60-120 minutes', 'Over 120 minutes']
counts = [count_less_than_15, count_15_to_30, count_30_to_60, count_60_to_120, count_over_120]

colors = ['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0']

wedges, texts, autotexts = ax.pie(counts, labels=labels, autopct='%1.1f%%',
                                   startangle=90, colors=colors,
                                   textprops=dict(color="w"), shadow=True)

plt.setp(autotexts, size=12, weight="bold")

ax.set_title("Time Answering Distribution")

ax.legend(wedges, labels, title="Time Answering", loc="center left",
          bbox_to_anchor=(1, 0, 0.5, 1))

ax.axis('equal')

plt.show()
